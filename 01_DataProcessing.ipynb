# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('data/NYC Motor Vehicle Collisions.csv')
# Out:
# /var/folders/h1/9jjzk_qj1l19pnl_kwfs0pwc0000gn/T/ipykernel_41147/57297897.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('data/NYC Motor Vehicle Collisions.csv')

# %%
data.shape
# Out:
# (2168156, 29)

# %%
data.head()
# Out:
#    CRASH DATE CRASH TIME   BOROUGH ZIP CODE  LATITUDE  LONGITUDE  \
# 0  09/11/2021       2:39       NaN      NaN       NaN        NaN
# 1  03/26/2022      11:45       NaN      NaN       NaN        NaN
# 2  11/01/2023       1:29  BROOKLYN  11230.0  40.62179 -73.970024
# 3  06/29/2022       6:55       NaN      NaN       NaN        NaN
# 4  09/21/2022      13:21       NaN      NaN       NaN        NaN
#
#                  LOCATION           ON STREET NAME CROSS STREET NAME  \
# 0                     NaN    WHITESTONE EXPRESSWAY         20 AVENUE
# 1                     NaN  QUEENSBORO BRIDGE UPPER               NaN
# 2  (40.62179, -73.970024)            OCEAN PARKWAY          AVENUE K
# 3                     NaN       THROGS NECK BRIDGE               NaN
# 4                     NaN          BROOKLYN BRIDGE               NaN
#
#   OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 0             NaN  ...                    Unspecified
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2168156 entries, 0 to 2168155
# Data columns (total 29 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   CRASH DATE                     object
#  1   CRASH TIME                     object
#  2   BOROUGH                        object
#  3   ZIP CODE                       object
#  4   LATITUDE                       float64
#  5   LONGITUDE                      float64
#  6   LOCATION                       object
#  7   ON STREET NAME                 object
#  8   CROSS STREET NAME              object
#  9   OFF STREET NAME                object
#  10  NUMBER OF PERSONS INJURED      float64
#  11  NUMBER OF PERSONS KILLED       float64
#  12  NUMBER OF PEDESTRIANS INJURED  int64
#  13  NUMBER OF PEDESTRIANS KILLED   int64
#  14  NUMBER OF CYCLIST INJURED      int64
#  15  NUMBER OF CYCLIST KILLED       int64
#  16  NUMBER OF MOTORIST INJURED     int64
# ...

# %%
data.describe()
# Out:
#            LATITUDE     LONGITUDE  NUMBER OF PERSONS INJURED  \
# count  1.928322e+06  1.928322e+06               2.168138e+06
# mean   4.061170e+01 -7.372303e+01               3.217461e-01
# std    2.136555e+00  3.991975e+00               7.096879e-01
# min    0.000000e+00 -2.013600e+02               0.000000e+00
# 25%    4.066746e+01 -7.397465e+01               0.000000e+00
# 50%    4.072044e+01 -7.392693e+01               0.000000e+00
# 75%    4.076962e+01 -7.386669e+01               0.000000e+00
# max    4.334444e+01  0.000000e+00               4.300000e+01
#
#        NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# count              2.168125e+06                   2.168156e+06
# mean               1.553416e-03                   5.868628e-02
# std                4.160388e-02                   2.482746e-01
# min                0.000000e+00                   0.000000e+00
# 25%                0.000000e+00                   0.000000e+00
# ...

# %% [markdown]
# ### Initial Cleanup

# %%
data['CRASH DATETIME'] = pd.to_datetime(data['CRASH DATE'] + ' ' + data['CRASH TIME'], errors='coerce')

# %%
data.drop(['CRASH DATE', 'CRASH TIME'], axis=1, inplace=True)

# %%
# Drop duplicate rows if any
data.drop_duplicates(inplace=True)

# %% [markdown]
# ### Handling Missing Values

# %%
# Check missing values
missing = data.isnull().sum().sort_values(ascending=False)

# %%
missing
# Out:
# VEHICLE TYPE CODE 5              2158714
# CONTRIBUTING FACTOR VEHICLE 5    2158411
# VEHICLE TYPE CODE 4              2133788
# CONTRIBUTING FACTOR VEHICLE 4    2132507
# VEHICLE TYPE CODE 3              2017661
# CONTRIBUTING FACTOR VEHICLE 3    2011713
# OFF STREET NAME                  1793106
# CROSS STREET NAME                 827260
# ZIP CODE                          670358
# BOROUGH                           670089
# ON STREET NAME                    467424
# VEHICLE TYPE CODE 2               428252
# CONTRIBUTING FACTOR VEHICLE 2     344214
# LONGITUDE                         239834
# LOCATION                          239834
# LATITUDE                          239834
# VEHICLE TYPE CODE 1                15323
# CONTRIBUTING FACTOR VEHICLE 1       7475
# NUMBER OF PERSONS KILLED              31
# NUMBER OF PERSONS INJURED             18
# COLLISION_ID                           0
# NUMBER OF MOTORIST INJURED             0
# NUMBER OF MOTORIST KILLED              0
# ...

# %%
plt.figure(figsize=(12,6))
sns.heatmap(data.isnull(), cbar=False, cmap='coolwarm')
plt.title('Missing Values Heatmap')
plt.show()

# %%
# Drop rows with missing target columns or critical location data
data.dropna(subset=['LATITUDE', 'LONGITUDE', 'CRASH DATETIME'], inplace=True)

# %%
# Remaining: drop columns with too many nulls (e.g., if >90% are null)
null_threshold = 0.9
to_drop = data.columns[data.isnull().mean() > null_threshold]
data.drop(columns=to_drop, inplace=True)

# %%
# Fill missing boroughs based on ZIP CODE if possible
if 'ZIP CODE' in data.columns and 'BOROUGH' in data.columns:
    zip_borough_map = data.dropna(subset=['ZIP CODE', 'BOROUGH']).drop_duplicates(subset=['ZIP CODE'])[['ZIP CODE', 'BOROUGH']]
    zip_borough_dict = dict(zip(zip_borough_map['ZIP CODE'], zip_borough_map['BOROUGH']))
    data['BOROUGH'] = data['BOROUGH'].fillna(data['ZIP CODE'].map(zip_borough_dict))

# %%
# For categorical features: fill with 'Unspecified'
cat_cols = [col for col in data.columns if data[col].dtype == 'object']
data[cat_cols] = data[cat_cols].fillna('Unspecified')

# %%
# For numerical features: fill with 0
num_cols = [col for col in data.columns if data[col].dtype in ['int64', 'float64']]
data[num_cols] = data[num_cols].fillna(0)

# %%
# Lowercase column names for consistency
data.columns = [col.lower().replace(' ', '_') for col in data.columns]

# %%
data['crash_datetime'] = pd.to_datetime(data['crash_datetime'], errors='coerce')

# %%
print("Data shape after cleaning:", data.shape)
print("Remaining missing values:", data.isnull().sum().sum())
# Out:
# Data shape after cleaning: (1928322, 22)
# Remaining missing values: 0

# %%
data.head()
# Out:
#         borough     zip_code   latitude  longitude                 location  \
# 2      BROOKLYN      11230.0  40.621790 -73.970024   (40.62179, -73.970024)
# 9      BROOKLYN      11208.0  40.667202 -73.866500    (40.667202, -73.8665)
# 10     BROOKLYN      11233.0  40.683304 -73.917274  (40.683304, -73.917274)
# 12  Unspecified  Unspecified  40.709183 -73.956825  (40.709183, -73.956825)
# 13        BRONX      10475.0  40.868160 -73.831480    (40.86816, -73.83148)
#
#                 on_street_name cross_street_name              off_street_name  \
# 2                OCEAN PARKWAY          AVENUE K                  Unspecified
# 9                  Unspecified       Unspecified      1211      LORING AVENUE
# 10             SARATOGA AVENUE    DECATUR STREET                  Unspecified
# 12  BROOKLYN QUEENS EXPRESSWAY       Unspecified                  Unspecified
# 13                 Unspecified       Unspecified  344       BAYCHESTER AVENUE
#
# ...

# %%
data.to_csv('data/NYC_Motor_Vehicle_Collisions_Cleaned.csv', index=False)
